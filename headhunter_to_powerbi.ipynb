# %%
import time
import random
import logging
import requests
import psycopg2
import schedule
import json
import os
pd.set_option('display.max_columns', None)

# %%
hh_api_token = 'GP4E5D9L7BQJ5CV07EN76NINTE8RU9SMFHCC4O24E5OJOUVOF2OUJAJ04JC7JGA5'

# %%
start = time.time()
import pandas as pd
A=[]
B=[]
for i in range(20): #"description": "you can't look up more than 2000 items in the list",
    try:
        s='https://api.hh.ru/vacancies?text=SQL&specialization=1&per_page=100&page='+str(i) ##можно вместо SQL другой текст пробовать.
        l='https://api.hh.ru/vacancies?text=качества%20данных&specialization=1&per_page=100&page'+str(i)
        A.append(s)
        A.append(l)
    except:
        continue
for i in A:
    response=requests.get(i)
    try:
        B.append(pd.DataFrame(response.json()['items']))
    except KeyError:
        continue
df=pd.concat(B, axis=0).reset_index()   
end = time.time()
print(end - start) #seconds
# Out:
# 31.568798065185547

# %%
"""
https://ru.stackoverflow.com/questions/1222089/%d0%9a%d0%b0%d0%ba-%d1%81-hh-ru-%d1%81%d0%bf%d0%b0%d1%80%d1%81%d0%b8%d1%82%d1%8c-%d0%b1%d0%be%d0%bb%d0%b5%d0%b5-2000-%d0%b7%d0%b0%d0%bf%d0%b8%d1%81%d0%b5%d0%b9#:~:text=%D0%9D%D0%B0%D0%BF%D1%80%D0%B8%D0%BC%D0%B5%D1%80,%20%D0%B2%D0%BE%D0%B7%D0%BC%D0%BE%D0%B6%D0%B5%D0%BD%20%D0%B7%D0%B0%D0%BF%D1%80%D0%BE%D1%81
К сожалению HH не выдаёт больше 2000 вакансий ни по какому запросу, ни через API, ни через браузер. 
"""

# %%
df.head(5)
# Out:
#    index         id  premium  \
# 0      0   93343681    False
# 1      1  106717345    False
# 2      2  107157266    False
# 3      3  107047878    False
# 4      4  107155283    False
#
#                                                 name  \
# 0                             QA Automation Engineer
# 1                Начинающий специалист - Тестировщик
# 2  Системный администратор в автомобильный бизнес...
# 3                                 Junior QA Engineer
# 4                                        BI аналитик
#
#                                          department  has_test  \
# 0  {'id': '866666-866666-IT', 'name': 'BetBoom.IT'}     False
# 1                                              None     False
# 2                                              None     False
# 3                                              None      True
# 4                                              None     False
#
#    response_letter_required  \
# 0                     False
# ...

# %%
dfn=pd.json_normalize(df.to_dict(orient='records'))[['id','name','salary','salary.from','salary.to','salary.currency','salary.gross','created_at', 'area.name','employer.name','schedule.name','employer.accredited_it_employer']]
dfn.head(5)
# Out:
#           id                                               name  salary  \
# 0   93343681                             QA Automation Engineer     NaN
# 1  106717345                Начинающий специалист - Тестировщик     NaN
# 2  107157266  Системный администратор в автомобильный бизнес...     NaN
# 3  107047878                                 Junior QA Engineer     NaN
# 4  107155283                                        BI аналитик     NaN
#
#    salary.from  salary.to salary.currency salary.gross  \
# 0          NaN        NaN             NaN          NaN
# 1      80000.0   123000.0             RUR        False
# 2     150000.0        NaN             RUR         True
# 3      60000.0    90000.0             RUR        False
# 4     400000.0        NaN             KZT        False
#
#                  created_at        area.name             employer.name  \
# 0  2024-08-30T11:19:17+0300           Москва                   BetBoom
# ...

# %%
dfn['name'] = dfn['name'].str.lower()

# %%
import datetime
df_dq=dfn[dfn['name'].str.contains('dq|data quality|качества|dwh|data steward|dg|data governance', na=False)]
df_dq['dateedit']=datetime.datetime.now()
result=df_dq[['dateedit','id','name','salary','salary.from','salary.to','salary.currency','salary.gross','created_at', 'area.name','employer.name','schedule.name','employer.accredited_it_employer']]
result
# Out:
# C:\Users\Павел\AppData\Local\Temp\ipykernel_19232\3647048960.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dq['dateedit']=datetime.datetime.now()
#                        dateedit         id                           name  \
# 459  2024-09-13 09:53:42.169659  107173329                dwh разработчик
# 612  2024-09-13 09:53:42.169659  106572502                   аналитик dwh
# 1420 2024-09-13 09:53:42.169659  107129025  аналитик sql- качества данных
# 1868 2024-09-13 09:53:42.169659  106085111         аналитик dwh, удаленно
# 2416 2024-09-13 09:53:42.169659  105880125       аналитик качества данных
# 3417 2024-09-13 09:53:42.169659  106406221   junior разработчик dwh (rms)
# ...

# %%
#Теперь это укладываем в базу в стейдж слой
"""
CREATE TABLE IF NOT EXISTS public.vcns
(
    dateedit timestamp without time zone,
    id integer NOT NULL,
    name character varying COLLATE pg_catalog."default",
    salary character varying COLLATE pg_catalog."default",
    salary_from character varying COLLATE pg_catalog."default",
    salary_to character varying COLLATE pg_catalog."default",
    salary_currency character varying COLLATE pg_catalog."default",
    salary_gross character varying COLLATE pg_catalog."default",
    created_at timestamp with time zone,
    area_name character varying COLLATE pg_catalog."default",
    employer_name character varying COLLATE pg_catalog."default",
    schedule_name character varying COLLATE pg_catalog."default",
    employer_accredited_it character varying COLLATE pg_catalog."default",
    CONSTRAINT vcns_pkey PRIMARY KEY (id)
)
"""
# Out:
# '\nCREATE TABLE IF NOT EXISTS public.vcns\n(\n    dateedit timestamp without time zone,\n    id integer NOT NULL,\n    name character varying COLLATE pg_catalog."default",\n    salary character varying COLLATE pg_catalog."default",\n    salary_from character varying COLLATE pg_catalog."default",\n    salary_to character varying COLLATE pg_catalog."default",\n    salary_currency character varying COLLATE pg_catalog."default",\n    salary_gross character varying COLLATE pg_catalog."default",\n    created_at timestamp with time zone,\n    area_name character varying COLLATE pg_catalog."default",\n    employer_name character varying COLLATE pg_catalog."default",\n    schedule_name character varying COLLATE pg_catalog."default",\n    employer_accredited_it character varying COLLATE pg_catalog."default",\n    CONSTRAINT vcns_pkey PRIMARY KEY (id)\n)\n'

# %%
db_config = {
    'dbname': 'tst',
    'user': 'postgres',
    'password': 'postgres',
    'host': '127.0.0.1',
    'port': '5432'
}
from sqlalchemy import create_engine
postgresql_url = 'postgresql://postgres:postgres@localhost:5432/tst'
engine = create_engine(postgresql_url)

# %%
import psycopg2
import pandas as pd
try:
    # пытаемся подключиться к базе данных
    conn = psycopg2.connect(dbname='tst', user='postgres', password='postgres',
                            host='127.0.0.1', port='5432')

except:
    # в случае сбоя подключения будет выведено сообщение в STDOUT
    print('Can`t establish connection to database')

query = """SELECT * FROM public.vcns;"""
pd.read_sql(query, conn)
# Out:
# C:\Users\Павел\AppData\Local\Temp\ipykernel_19232\329261950.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, conn)
#                     dateedit         id                           name salary  \
# 0 2024-09-13 09:22:12.889469  106572502                   аналитик dwh    NaN
# 1 2024-09-13 09:22:12.889469  107173329                dwh разработчик    NaN
# 2 2024-09-13 09:22:12.889469  107129025  аналитик sql- качества данных    NaN
# 3 2024-09-13 09:22:12.889469  106085111         аналитик dwh, удаленно    NaN
# 4 2024-09-13 09:22:12.889469  105880125       аналитик качества данных    NaN
# 5 2024-09-13 09:22:12.889469  106406221   junior разработчик dwh (rms)    NaN
# 6 2024-09-13 09:22:12.889469  102865677   аналитик bi (отчетность dwh)    NaN
# ...

# %%
result_tuple=[tuple(result) for result in result.to_numpy()]
from psycopg2.extras import execute_values
insert_sql = "INSERT INTO public.vcns  VALUES %s"
cur = conn.cursor()
execute_values(cur, insert_sql, result_tuple)
conn.commit()

# %%
#Проверяем + закрываем соединение
try:
    conn = psycopg2.connect(dbname='tst', user='postgres', password='postgres',
                            host='127.0.0.1', port='5432')
except:
    print('Can`t establish connection to database')
query = """SELECT * FROM public.vcns;"""
pd.read_sql(query, conn)
# Out:
# C:\Users\Павел\AppData\Local\Temp\ipykernel_19232\4006180567.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, conn)
#                      dateedit         id                           name  \
# 0  2024-09-13 09:22:12.889469  106572502                   аналитик dwh
# 1  2024-09-13 09:22:12.889469  107173329                dwh разработчик
# 2  2024-09-13 09:22:12.889469  107129025  аналитик sql- качества данных
# 3  2024-09-13 09:22:12.889469  106085111         аналитик dwh, удаленно
# 4  2024-09-13 09:22:12.889469  105880125       аналитик качества данных
# 5  2024-09-13 09:22:12.889469  106406221   junior разработчик dwh (rms)
# 6  2024-09-13 09:22:12.889469  102865677   аналитик bi (отчетность dwh)
# 7  2024-09-13 09:22:12.889469  107196741            data engineer (dwh)
# ...

# %%
#Закрываем соединение
conn.close()

# %%
#Дальше делаем ETL, который будет докидывать новые записи с флагом актуал=1 и ставить флаг=0 при пропаже существующих
#Можно вьюшку написать. Прототип кода ниже

# %%
"""
with dr as
(
  select dateedit
       , id
	   , name
	   , salary
	   , salary_from
	   , salary_to
	   , salary_currency
	   , salary_gross
	   , created_at
	   , area_name
	   , employer_name
	   , schedule_name
	   , employer_accredited_it
	   , dense_rank()over(partition by id order by dateedit desc) rn
	from public.vcns
)
  insert into ods_table
  select dr.dateedit
       , dr.id
	   , dr.name
	   , dr.salary
	   , dr.salary_from
	   , dr.salary_to
	   , dr.salary_currency
	   , dr.salary_gross
	   , dr.created_at
	   , dr.area_name
	   , dr.employer_name
	   , dr.schedule_name
	   , dr.employer_accredited_it 
       , 1 is_actual
    from dr 
   where dr.rn=1
     and not exists
	               (
				    select 1
					  from dr d
					 where d.id=dr.id
                   )

  update ods_table
     set is_actual=0
   where not exists 
                   (
                    select 1
                      from dr d 
					 where d.id=ods_table.id
                   )
"""
